# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
from sklearn.datasets import make_classification

# %%
x, y = make_classification(
    n_samples = 1000,
    n_features = 3,
    n_redundant = 1,
    n_classes = 2,
    random_state = 999
)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap='viridis', edgecolor='k', s=50, alpha=0.7)
plt.title("Scatter Plot of Synthetic Classification Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.colorbar(label="Class")
plt.show()

# %%
# Create a DataFrame with the features and target
df = pd.DataFrame(x, columns=['Feature_1', 'Feature_2', 'Feature_3'])
df['Target'] = y

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Feature_1  Feature_2  Feature_3  Target
# 0  -0.335050   0.028527   1.161931       0
# 1  -1.377463  -0.405821   0.443596       0
# 2  -1.045200  -0.723348  -3.104704       1
# 3   2.085399   0.758149   0.519318       1
# 4   1.762419   0.822554   1.945117       1

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5, algorithm='auto')

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.906060606060606

# %%
classification_report(y_pred, y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.93      0.89      0.91       178\n           1       0.88      0.93      0.90       152\n\n    accuracy                           0.91       330\n   macro avg       0.91      0.91      0.91       330\nweighted avg       0.91      0.91      0.91       330\n'

# %%
confusion_matrix(y_pred, y_test)
# Out:
# array([[158,  20],
#        [ 11, 141]], dtype=int64)

# %%
knn.predict([[-0.335050,   0.028527,   1.161931 ]])
# Out:
# array([0])

# %%
knn.predict([[1.762419,   0.822554,   1.945117]])
# Out:
# array([1])
