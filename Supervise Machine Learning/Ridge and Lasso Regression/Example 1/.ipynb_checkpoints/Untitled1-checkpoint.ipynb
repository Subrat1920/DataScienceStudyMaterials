# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('cleaned_dataset.csv')
data.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  \
# 0           0    1      6  2012           32   71   12    0.7  57.1  2.5
# 1           1    2      6  2012           30   73   13    4.0  55.7  2.7
# 2           2    3      6  2012           29   80   14    2.0  48.7  2.2
# 3           3    4      6  2012           30   64   14    0.0  79.4  5.2
# 4           4    5      6  2012           32   60   14    0.2  77.1  6.0
#
#      DC  ISI  BUI  FWI  Classes    Region
# 0   8.2  0.6  2.8  0.2          0       0
# 1   7.8  0.6  2.9  0.2          0       0
# 2   7.6  0.3  2.6  0.1          0       0
# 3  15.4  2.2  5.6  1.0          0       0
# 4  17.6  1.8  6.5  0.9          0       0

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           32   71   12    0.7  57.1  2.5   8.2  0.6  2.8
# 1    2      6  2012           30   73   13    4.0  55.7  2.7   7.8  0.6  2.9
# 2    3      6  2012           29   80   14    2.0  48.7  2.2   7.6  0.3  2.6
# 3    4      6  2012           30   64   14    0.0  79.4  5.2  15.4  2.2  5.6
# 4    5      6  2012           32   60   14    0.2  77.1  6.0  17.6  1.8  6.5
#
#    FWI  Classes    Region
# 0  0.2          0       0
# 1  0.2          0       0
# 2  0.1          0       0
# 3  1.0          0       0
# 4  0.9          0       0

# %%
data.drop(columns=['day', 'month', 'year'], inplace=True)
data.head()
# Out:
#    Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI  Classes    \
# 0           32   71   12    0.7  57.1  2.5   8.2  0.6  2.8  0.2          0
# 1           30   73   13    4.0  55.7  2.7   7.8  0.6  2.9  0.2          0
# 2           29   80   14    2.0  48.7  2.2   7.6  0.3  2.6  0.1          0
# 3           30   64   14    0.0  79.4  5.2  15.4  2.2  5.6  1.0          0
# 4           32   60   14    0.2  77.1  6.0  17.6  1.8  6.5  0.9          0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data['Classes  '].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %% [markdown]
# ##### Independent and Dependent Features

# %%
x = data.drop('FWI', axis=1)
y = data['FWI']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws     Rain       FFMC       DMC  \
# Temperature     1.000000 -0.656205 -0.262846 -0.360334  0.704081  0.516175
#  RH            -0.656205  1.000000  0.265810  0.245462 -0.676423 -0.431435
#  Ws            -0.262846  0.265810  1.000000  0.198940 -0.188454 -0.023881
# Rain           -0.360334  0.245462  0.198940  1.000000 -0.542686 -0.292730
# FFMC            0.704081 -0.676423 -0.188454 -0.542686  1.000000  0.625532
# DMC             0.516175 -0.431435 -0.023881 -0.292730  0.625532  1.000000
# DC              0.396926 -0.229554  0.077952 -0.296041  0.503857  0.855702
# ISI             0.624169 -0.689792 -0.013488 -0.335801  0.740523  0.678075
# BUI             0.490925 -0.372187  0.016300 -0.303417  0.609641  0.979212
# Classes         0.551994 -0.451274 -0.092707 -0.359443  0.772184  0.609409
# Region         -0.248282  0.417596  0.237981  0.101328 -0.269207 -0.199186
#
#                    DC       ISI       BUI  Classes      Region
# ...

# %% [markdown]
# ### Checking for Multicolinearity

# %%
plt.figure(figsize=(10,6))
corr = x_train.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
def data_correlation(dataset, threshold):
    col_corr=set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold is set by domain expert
corr_feature = data_correlation(x_train, 0.85)

# %% [markdown]
# now drop the highly related feature

# %%
x_train.head()
# Out:
#      Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI   BUI  Classes    \
# 97            31   62   15    0.0  83.3   5.8  17.7  3.8   6.4          1
# 141           30   78   14    0.0  81.0   6.3  31.6  2.6   8.4          1
# 192           35   63   13    0.0  88.9  21.7  77.0  7.1  25.5          1
# 68            39   43   12    0.0  91.7  16.5  30.9  9.6  16.4          1
# 119           24   54   18    0.1  79.7   4.3  15.2  1.7   5.1          0
#
#      Region
# 97        0
# 141       1
# 192       1
# 68        0
# 119       0

# %%
x_test
# Out:
#      Temperature   RH   Ws  Rain   FFMC   DMC     DC  ISI   BUI  Classes    \
# 24            34   70   16    0.0  86.0  12.8   25.6  5.4  12.7          1
# 6             35   44   17    0.2  85.6   9.9   28.9  5.4  10.7          1
# 152           27   75   19    1.2  55.7   2.4    8.3  0.8   2.8          0
# 232           28   84   18    0.0  83.8  13.5   49.3  4.5  16.0          1
# 238           31   54   11    0.0  82.0   6.0   16.3  2.5   6.2          0
# ..           ...  ...  ...    ...   ...   ...    ...  ...   ...        ...
# 162           31   75   13    0.1  75.1   7.9   27.7  1.5   9.2          0
# 178           33   76   15    0.0  86.5  24.4  117.8  5.6  32.1          1
# 224           29   88   13    0.0  71.0   2.6   16.6  1.2   3.7          0
# 230           32   49   11    0.0  89.4   9.8   33.1  6.8  11.3          1
# 154           33   78   17    0.0  80.1   4.6   18.5  2.7   5.7          0
#
#      Region
# 24        0
# 6         0
# 152       1
# 232       1
# ...

# %%
x_train.shape, x_test.shape
# Out:
# ((182, 11), (61, 11))

# %% [markdown]
# ## Feature Scaling Or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
plt.figure(figsize=(10,6))
plt.suptitle('Box Plot for Outliers', fontsize=19)

plt.subplot(1,2,1)
sns.boxplot(x_train)
plt.xlabel('Box Plot for X_train data')

plt.subplot(1,2,2)
sns.boxplot(x_train_scaled)
plt.xlabel('Box Plot for X_train data')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score
y_pred = regression.predict(x_test_scaled)
mae = mean_absolute_error(y_pred, y_test)
r2_score = r2_score(y_pred, y_test)
mae, r2_score
# Out:
# (0.5764956583016979, 0.9877318442447521)

# %%
plt.scatter(y_test, y_pred)

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

lasso = Lasso()
lasso.fit(x_train_scaled, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso.predict(x_test_scaled)

# %%
mae=mean_absolute_error(y_pred, y_test)
r2_score = r2_score(y_pred, y_test)
mae, r2_score
# Out:
# (1.007851434480098, 0.941419677575402)

# %%
plt.scatter(y_test, y_pred)

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge()
ridge.fit(x_train_scaled, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mae = mean_absolute_error(y_pred, y_test)
r2 = r2_score(y_test, y_pred)
mae, r2
# Out:
# (0.5963516355411435, 0.9875954005784419)

# %%
plt.scatter(y_test, y_pred)

# %%
ridge.coef_
# Out:
# array([-0.06102718, -0.23008432,  0.03481259, -0.02482791, -0.86530161,
#         1.09239362, -0.1921991 ,  4.84869219,  2.53032303,  0.48926473,
#         0.2923456 ])

# %%
lasso.coef_
# Out:
# array([ 0.        , -0.        ,  0.        , -0.        ,  0.        ,
#         0.63337571,  0.        ,  4.18197159,  2.04615571,  0.        ,
#         0.        ])

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic = ElasticNet()
elastic.fit(x_train_scaled, y_train)
# Out:
# ElasticNet()

# %%
y_pred = elastic.predict(x_test_scaled)

# %%
mae = mean_absolute_error(y_pred, y_test)
r2 = r2_score(y_pred, y_test)
mae, r2
# Out:
# (1.3748993067556698, 0.8904964777687733)

# %%
plt.scatter(y_test, y_pred)

# %%
elastic.coef_
# Out:
# array([ 0.12805867, -0.4394192 ,  0.        , -0.        ,  0.18841463,
#         1.28198588,  0.59404728,  2.27481956,  1.18287603,  0.76559307,
#        -0.        ])

# %%
from sklearn.linear_model import LassoCV
lass = LassoCV()
