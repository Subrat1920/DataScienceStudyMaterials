# %%
from pydataset import data
# Out:
# initiated datasets repo at: C:\Users\HP\.pydataset/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
pima=data('Pima.tr')

# %%
pima.plot(kind='scatter', x='skin', y='bmi')
plt.show()

# %%
# Train Test Split
X_train, X_test, y_train, y_test= train_test_split(pima.skin, pima.bmi)

# %%
plt.scatter(X_train, y_train, label='Training Data', color='r', alpha=.7)
plt.scatter(X_test, y_test, label='Testing Data', color='g', alpha=.7)
plt.show()

# %%
linear = LinearRegression()

# %%
linear.fit(X_train.values.reshape(-1,1), y_train.values)
# Out:
# LinearRegression()

# %%
prediction = linear.predict(X_test.values.reshape(-1,1))
plt.plot(X_test, prediction, label='Linear Regression', color='b')
plt.scatter(X_test, y_test, label='Actual Test Data', color='g', alpha=0.7)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
db = datasets.load_diabetes()
df=pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target']=diabetes.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
x=df.bmi
y=df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
X_train=X_train.values.reshape(-1,1)

# %%
mod=LinearRegression()
mod.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=mod.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 y_pred=mod.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# ...

# %%
comp=pd.read_csv('1000_Companies.csv')
comp.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
x=comp.iloc[:,:-1].values
y=comp.iloc[:,4].values

# %%
X_train, X_test, y_train, y_test=train_test_split(x,y, test_size=0.3, random_state=42)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 sns.heatmap(comp.corr(), annot=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
from numpy import random

# %%
sal=np.random.randint(100000,500000,100)
sal
# Out:
# array([116133, 262099, 353304, 301653, 130931, 105738, 323935, 431447,
#        220730, 356513, 491849, 397745, 467860, 449655, 444259, 127549,
#        291486, 136431, 282034, 300508, 383648, 174120, 306377, 302383,
#        181462, 207065, 389446, 223660, 241530, 436453, 137808, 467384,
#        472230, 251044, 498725, 416696, 313035, 333663, 198949, 294202,
#        344079, 214518, 245825, 202800, 238782, 261600, 118963, 467035,
#        228577, 239856, 249740, 284357, 429376, 217322, 282613, 361641,
#        320188, 243371, 182905, 424924, 159014, 221365, 373535, 278869,
#        385386, 104707, 446737, 262028, 293796, 230716, 428958, 148258,
#        129887, 100001, 356980, 494026, 153289, 425257, 440992, 114662,
#        210601, 239899, 369381, 179203, 493943, 164142, 393896, 248667,
#        495064, 403263, 278092, 223301, 359610, 456944, 124437, 141186,
#        418045, 294460, 113499, 101722])

# %%
exp=np.random.randint(1, 5, 100)
exp
# Out:
# array([4, 2, 4, 4, 3, 2, 2, 1, 2, 1, 1, 3, 1, 3, 4, 4, 2, 2, 3, 2, 1, 4,
#        3, 4, 3, 4, 2, 4, 1, 4, 1, 3, 2, 1, 3, 3, 2, 2, 2, 3, 4, 2, 2, 3,
#        1, 3, 2, 3, 3, 2, 3, 1, 3, 3, 2, 3, 1, 3, 2, 3, 4, 3, 1, 3, 4, 2,
#        2, 1, 2, 2, 1, 1, 3, 1, 3, 4, 4, 4, 1, 4, 4, 1, 2, 4, 4, 2, 1, 1,
#        4, 3, 3, 2, 3, 1, 4, 1, 2, 4, 1, 3])

# %%
sns.histplot(x=sal, kde=True)
plt.show()

# %%
sns.boxplot(x=sal)
# Out:
# <Axes: >

# %%
sns.histplot(x=exp, kde=True)
plt.show()

# %%
sns.boxplot(x=exp)
plt.show()

# %%
X_train, X_test, y_train, y_test=train_test_split(sal, exp, test_size=0.3, random_state=42)

# %%
training=[X_train, X_test, y_train, y_test]

# %%
for i in training:
    sns.histplot(x=i, kde=True)
    plt.show()

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
X_train.reshape(-1,1)
# Out:
# array([[397745],
#        [467035],
#        [164142],
#        [241530],
#        [456944],
#        [105738],
#        [446737],
#        [104707],
#        [416696],
#        [291486],
#        [239856],
#        [498725],
#        [431447],
#        [141186],
#        [223660],
#        [300508],
#        [239899],
#        [207065],
#        [373535],
#        [449655],
#        [181462],
#        [301653],
#        [136431],
#        [198949],
#        [220730],
#        [440992],
#        [323935],
#        [385386],
#        [313035],
#        [403263],
#        [320188],
#        [101722],
#        [282613],
#        [202800],
#        [249740],
#        [262028],
#        [118963],
#        [293796],
#        [221365],
#        [294460],
#        [114662],
#        [214518],
#        [182905],
#        [228577],
#        [113499],
#        [243371],
#        [494026],
#        [472230],
#        [124437],
#        [424924],
#        [278869],
#        [493943],
# ...

# %%
X_train.shape
# Out:
# (70,)

# %%
y_train.reshape(1,-1)
# Out:
# array([[3, 3, 2, 1, 1, 2, 2, 2, 3, 2, 2, 3, 1, 1, 4, 2, 1, 4, 1, 3, 3, 4,
#         2, 2, 2, 1, 2, 4, 2, 3, 1, 3, 2, 3, 3, 1, 2, 2, 3, 4, 4, 2, 2, 3,
#         1, 3, 4, 2, 4, 3, 3, 4, 2, 4, 2, 3, 4, 4, 4, 1, 2, 3, 1, 2, 1, 4,
#         1, 4, 3, 1]])

# %%
y_train.shape
# Out:
# (70,)

# %%
reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 reg.fit(X_train, y_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
# ...

# %%
df=pd.read_csv('boston_house_prices.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
target=df.MEDV

# %%
target.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
X=df
y=target

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
# train test split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT  MEDV
# 5       18.7  394.12   5.21  28.7
# 116     17.8  393.30  12.04  21.2
# ...

# %%
X_train.drop('MEDV', axis=1)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.39651419,
#         -1.01531611,  0.60629225],
#        [-0.40200818, -0.50512499, -0.16208345, ...,  0.3870674 ,
#         -0.05366252, -0.19368088],
#        [-0.39721053, -0.50512499, -0.60948856, ...,  0.42854113,
#         -0.31132373, -0.39634074],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ...,  0.35987906,
#         -0.90549329,  0.1583073 ],
#        [ 0.92611293, -0.50512499,  1.00549958, ..., -2.87841346,
#          1.52750437, -1.02565293],
#        [-0.39030549, -0.50512499, -0.37135358, ..., -3.32828832,
#         -0.25218837, -0.4710049 ]])

# %%
X_test=scaler.transform(X_test)
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ...,  0.41241246,
#         -0.47605794,  0.06231052],
#        [-0.41105674,  1.26662874, -0.68165068, ...,  0.42854113,
#         -1.25185755,  1.00094566],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.35031705,
#          0.79535229, -1.00432031],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ...,  0.25688594,
#         -1.09697922,  2.87821594],
#        [ 0.25423453, -0.50512499,  1.00549958, ..., -2.98970133,
#          0.53487511, -0.92965616],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.33199949,
#          0.56585078, -1.1109834 ]])

# %%
from sklearn.model_selection import cross_val_score

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
mse=cross_val_score(reg, X_train, y_train, scoring='neg_mean_squared_error', cv=10)

# %%
np.mean(mse)
# Out:
# -3.31219873483259e-27

# %%
reg_predict=reg.predict(X_test)

# %%
reg_predict
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8, 21.5,
#        18.9,  7. , 21.2, 18.5, 29.8, 18.8, 10.2, 50. , 14.1, 25.2, 29.1,
#        12.7, 22.4, 14.2, 13.8, 20.3, 14.9, 21.7, 18.3, 23.1, 23.8, 15. ,
#        20.8, 19.1, 19.4, 34.7, 19.5, 24.4, 23.4, 19.7, 28.2, 50. , 17.4,
#        22.6, 15.1, 13.1, 24.2, 19.9, 24. , 18.9, 35.4, 15.2, 26.5, 43.5,
#        21.2, 18.4, 28.5, 23.9, 18.5, 25. , 35.4, 31.5, 20.2, 24.1, 20. ,
#        13.1, 24.8, 30.8, 12.7, 20. , 23.7, 10.8, 20.6, 20.8,  5. , 20.1,
#        48.5, 10.9,  7. , 20.9, 17.2, 20.9,  9.7, 19.4, 29. , 16.4, 25. ,
#        25. , 17.1, 23.2, 10.4, 19.6, 17.2, 27.5, 23. , 50. , 17.9,  9.6,
#        17.2, 22.5, 21.4, 12. , 19.9, 19.4, 13.4, 18.2, 24.6, 21.1, 24.7,
#         8.7, 27.5, 20.7, 36.2, 31.6, 11.7, 39.8, 13.9, 21.8, 23.7, 17.6,
#        24.4,  8.8, 19.2, 25.3, 20.4, 23.1, 37.9, 15.6, 45.4, 15.7, 22.6,
#        14.5, 18.7, 17.8, 16.1, 20.6, 31.6, 29.1, 15.6, 17.5, 22.5, 19.4,
# ...

# %%
sns.distplot(reg_predict-y_test, )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3668\3614664886.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(reg_predict-y_test, )
# <Axes: xlabel='MEDV', ylabel='Density'>

# %%
sal=np.random.randint(10000,2500000, 100)
exp=np.random.randint(0,10,100)

# %%
X_train, X_test, y_train, y_test=train_test_split(sal, exp, test_size=1/3, random_state=0)

# %%
reg=LinearRegression()

# %%
X_train=X_train.reshape(-1,1)
X_test=X_test.reshape(-1,1)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= reg.predict(X_test)  
x_pred= reg.predict(X_train)

# %%
plt.scatter(X_train, y_train, color='g')
plt.plot(X_train, x_pred, color='r')
plt.show()

# %%
set={
    'weight':[85,45,60,55,67,45,68,89,67,90,56,66,68,56,59,97,99,67,88,99],
    'height':[180,120,140,150,134,155,167,165,187,156,198,156,198,145,134,122,145,165,167,187]
}

# %%
len([180,120,140,150,134,155,167,165,187,156,198,156,198,145,134,122,145,165,167,187])
# Out:
# 20

# %%
df.head()
# Out:
#    weight  height
# 0      85     180
# 1      45     120
# 2      60     140
# 3      55     150
# 4      67     134

# %%
sns.boxplot(x=df.height)
# Out:
# <Axes: xlabel='height'>

# %%
sns.boxplot(x=df.weight)
# Out:
# <Axes: xlabel='weight'>

# %%
plt.scatter(x=df.weight, y=df.height)

# %%
data=pd.read_csv('weight.csv')

# %%
plt.scatter(x=data.weight, y=data.height)
plt.xlabel('Weight')
plt.ylabel('Height')
plt.show()

# %%
x=data.weight
y=data.height

# %%
X_train, X_test, y_train, y_test=train_test_split(x,y,test_size=0.3, random_state=42)

# %%
X_train=X_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3668\3125963867.py in ?()
# ----> 1 X_train=X_train.reshape(-1,1)
#       2 y_train=y_train.reshape(-1,1)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 2
#       1 reg=LinearRegression()
# ----> 2 reg.fit(X_train,y_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
# ...
