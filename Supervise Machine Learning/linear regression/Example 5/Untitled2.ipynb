# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
df.head())
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
X=df[['Experience Years']]
y=df.Salary

# %%
X.head()
# Out:
#    Experience Years
# 0               1.1
# 1               1.2
# 2               1.3
# 3               1.5
# 4               2.0

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
plt.scatter(X,y)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([ 69334.98315618,  64605.30338877,  64605.30338877,  83524.02245843,
#         45686.5843191 ,  61767.49552832, 117577.71678382,  85415.89436539,
#        126091.14036516,  50416.26408652,  82578.08650494,  57037.8157609 ])

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 5211.981371554558

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 35344480.17477033

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9439054952900567

# %% [markdown]
# ### for showing up of the best fit line of training and testing data

# %%
plt.scatter(X, y, color='green', label='X_test and Y_test')
plt.plot(X_test, y_pred, color='red', label='Best Fit Line')
plt.show()

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg=Ridge(alpha=1)

# %%
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_train_pred=ridge_reg.predict(X_train)
y_test_pred=ridge_reg.predict(X_test)

# %%
train_r2=r2_score(y_train, y_train_pred)
test_r2=r2_score(y_test, y_test_pred)
train_r2, test_r2
# Out:
# (0.9593006045374705, 0.9436652054886829)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, ridge_reg.predict(X), color='red', linewidth=2, label='Best Fit Line (Ridge Regression)')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Ridge Regression with L2 Regularization')
plt.legend()
plt.show()
