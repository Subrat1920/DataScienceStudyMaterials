# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('diamonds.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data.fillna(data.mean(numeric_only=True), inplace = True)
data.drop_duplicates(inplace=True)

# %%
sns.pairplot(
    data, x_vars='carat', y_vars='price', height =12, kind = 'scatter'
)
plt.xlabel("Carat")
plt.ylabel("Price")
plt.title("Diamond Price Prediction : Carat vs Price")
plt.show()

# %%
plt.figure(figsize = (12, 8))

sns.heatmap(
    data.corr(numeric_only = True), annot = True, cmap='coolwarm', linewidths = 0.5
)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.violinplot(x = 'carat', y='price', data = data)
plt.title("Violin Plot of Price By Carat")
plt.show()

# %%
# X = np.array(data['carat'])
# Y = np.array(data['price'])

print(data[['carat', 'price']])
# Out:
#        carat  price
# 0       0.23    326
# 1       0.21    326
# 2       0.23    327
# 3       0.29    334
# 4       0.31    335
# ...      ...    ...
# 53935   0.72   2757
# 53936   0.72   2757
# 53937   0.70   2757
# 53938   0.86   2757
# 53939   0.75   2757
#
# [53940 rows x 2 columns]

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split

# # Example data
# # X, Y should be defined or loaded here

# X_train, X_test, Y_train, Y_test = train_test_split(X, y, train_size=0.7, random_state=100)

# # Standardizing the features
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
from sklearn import linear_model

X = np.array(data['carat'])
Y = np.array(data['price'])

reg = linear_model.LinearRegression()
reg.fit(data[['carat']], data.price)
# Out:
# LinearRegression()

# %%
from numpy import random
prediction_carat = np.array(random.randint(1,100,50))
prediction_list = []
for i in prediction_carat:
    prediction=np.array(i).reshape(1,-1)
    prediction_list.append(prediction)
print(prediction_list)
# value_reshaped = np.array(prediction_carat).reshape(1,-1)
# prediction = reg.predict(value_reshaped)
# print(prediction)
# Out:
# [array([[40]]), array([[56]]), array([[80]]), array([[6]]), array([[55]]), array([[29]]), array([[79]]), array([[9]]), array([[89]]), array([[65]]), array([[15]]), array([[12]]), array([[58]]), array([[8]]), array([[2]]), array([[56]]), array([[13]]), array([[25]]), array([[50]]), array([[94]]), array([[32]]), array([[29]]), array([[93]]), array([[71]]), array([[34]]), array([[86]]), array([[8]]), array([[83]]), array([[69]]), array([[40]]), array([[59]]), array([[52]]), array([[54]]), array([[28]]), array([[90]]), array([[71]]), array([[13]]), array([[15]]), array([[37]]), array([[91]]), array([[5]]), array([[29]]), array([[4]]), array([[3]]), array([[4]]), array([[63]]), array([[4]]), array([[69]]), array([[77]]), array([[69]])]

# %%
plt.scatter(prediction_carat,prediction_list)
plt.xlabel("Carat")
plt.ylabel("Price")
plt.title("Prediction")
# Out:
# Text(0.5, 1.0, 'Prediction')
